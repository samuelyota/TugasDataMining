# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelyota/TugasDataMining/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('./data.csv')
df.head()
# Out:
#          Provinsi     SD    SMP    SMA     PT
# 0            ACEH  98.99  94.37  72.14  27.68
# 1  SUMATERA UTARA  98.34  89.00  67.10  16.94
# 2  SUMATERA BARAT  98.09  90.12  68.84  23.95
# 3            RIAU  97.68  88.28  65.41  15.34
# 4           JAMBI  98.27  88.08  59.99  15.64

# %%
df.shape
# Out:
# (34, 5)

# %%
df.columns
# Out:
# Index(['Provinsi', 'SD', 'SMP', 'SMA', 'PT'], dtype='object')

# %%
df.head()
# Out:
#          Provinsi     SD    SMP    SMA     PT
# 0            ACEH  98.99  94.37  72.14  27.68
# 1  SUMATERA UTARA  98.34  89.00  67.10  16.94
# 2  SUMATERA BARAT  98.09  90.12  68.84  23.95
# 3            RIAU  97.68  88.28  65.41  15.34
# 4           JAMBI  98.27  88.08  59.99  15.64

# %%
df.shape
# Out:
# (34, 5)

# %%
from sklearn.preprocessing import LabelEncoder

lb=LabelEncoder()
df['PT'] = lb.fit_transform(df['PT'])
df
# Out:
#                 Provinsi     SD    SMP    SMA  PT
# 0                   ACEH  98.99  94.37  72.14  30
# 1         SUMATERA UTARA  98.34  89.00  67.10  18
# 2         SUMATERA BARAT  98.09  90.12  68.84  28
# 3                   RIAU  97.68  88.28  65.41  13
# 4                  JAMBI  98.27  88.08  59.99  14
# 5       SUMATERA SELATAN  97.95  86.45  56.54   6
# 6               BENGKULU  98.41  90.97  62.86  20
# 7                LAMPUNG  97.94  86.39  56.24   1
# 8   KEP. BANGKA BELITUNG  97.28  84.53  49.92  32
# 9              KEP. RIAU  97.61  96.57  68.17  33
# 10           DKI JAKARTA  98.14  92.38  59.72  22
# 11            JAWA BARAT  97.89  85.97  50.36   2
# 12           JAWA TENGAH  98.61  88.38  54.76   3
# 13         DI YOGYAKARTA  99.43  97.66  75.60  31
# 14            JAWA TIMUR  98.27  90.11  58.54   5
# 15                BANTEN  98.22  88.47  56.01  10
# 16                  BALI  98.38  92.36  68.22  23
# 17   NUSA TENGGARA BARAT  97.85  91.40  60.09  19
# ...

# %%
df.describe().T
# Out:
#     count  mean       std  min   25%   50%    75%   max
# PT   34.0  16.5  9.958246  0.0  8.25  16.5  24.75  33.0

# %%
x=df.iloc[:,1:32].values # x
y=df.iloc[:,0].values #y

# %%
sns.pairplot(df,vars=['Provinsi', 'SD', 'SMP', 'SMA', 'PT'], hue ='PT')

plt.ioff
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4049fc4f82e4> in <module>()
# ----> 1 sns.pairplot(df,vars=['Provinsi', 'SD', 'SMP', 'SMA', 'PT'], hue ='PT')
#       2
#       3 plt.ioff
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2128         diag_kws.setdefault("fill", True)
#    2129         diag_kws.setdefault("warn_singular", False)
# -> 2130         grid.map_diag(kdeplot, **diag_kws)
#    2131
# ...

# %%
sns.countplot (df['PT'])

plt.ioff
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.ioff>
